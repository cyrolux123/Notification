# %%
# import os
# from dotenv import load_dotenv
# from groq import Groq

# # Load environment variables from .env file
# load_dotenv()

# # Get the API key
# api_key = os.getenv("GROQ_API_KEY")

# # Initialize the Groq client with the API key
# client = Groq(api_key=api_key)

# # Your request logic
# completion = client.chat.completions.create(
#     model="llama-3.3-70b-specdec",
#     messages=[
#         {
#             "role": "system",
#             "content": (
#                 "You are an expert in news content analysis and dataset generation for machine learning models. "
#                 "Your goal is to create a high-quality CSV dataset specifically for a Nepali news application. "
#                 "The dataset should include the following fields:\n"
#                 "1. **Headline**: The main title of the news article.\n"
#                 "2. **Description**: A brief body of the news article.\n"
#                 "3. **Notification Priority**: A binary value (1 or 0), where:\n"
#                 "- 1 indicates the article is highly relevant and should be sent as a notification.\n"
#                 "- 0 indicates the article is not suitable for notification.\n"
#                 "\n"
#                 "Ensure the dataset:\n"
#                 "- Contains diverse news categories like Employment, Sports, Tourism, Auto, National News, "
#                 "Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, Education, "
#                 "and World.\n"
#                 "- Prioritizes news relevance, urgency, and potential user interest for notification prioritization.\n"
#                 "- Focuses on the Nepali context, using culturally and socially relevant topics.\n"
#                 "- Avoids bias and ensures balance in the selection process.\n"
#                 "\n"
#                 "Generate realistic samples that align with user preferences for push notifications. "
#                 "Include headlines and descriptions in Nepali. Provide 100 examples in CSV format."
#             ),
#         },
#         {
#             "role": "user",
#             "content": (
#                 "I am developing a news app with a notification section. I want to integrate a machine learning model "
#                 "that takes two parameters: headline and body of the news. The model will categorize which news to send "
#                 "as notifications.\n\n"
#                 "Please help create a Nepali dataset with:\n"
#                 "1. Headline: The main title of the news article.\n"
#                 "2. Description: A brief summary of the news article.\n"
#                 "3. Notification Priority: A binary value (1 for include in notification, 0 for not include).\n\n"
#                 "The dataset should include news from diverse categories such as Employment, Sports, Tourism, Auto, "
#                 "National News, Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, "
#                 "Education, and World. Ensure it reflects culturally relevant topics and avoids bias.\n\n"
#                 "Generate realistic samples in csv format taking Headline before first comma Description before second "
#                 "comma and Notification Priority after second comma in Nepali that align with user preferences for notifications."
#             ),
#         },
#     ],
#     temperature=0.68,
#     max_tokens=210,
#     top_p=1,
#     stream=True,
# )

# # Stream the output
# for chunk in completion:
#     print(chunk.choices[0].delta.content or "", end="")

# %%
import os
import csv
import time
from dotenv import load_dotenv
from groq import Groq
from requests.exceptions import RequestException

# Load environment variables from .env file
load_dotenv()

# Get the API key
api_key = os.getenv("GROQ_API_KEY")

# Initialize the Groq client with the API key
client = Groq(api_key=api_key)

# Prepare CSV file to save the results
output_file = "nepali_news_dataset.csv"
fields = ['Headline', 'Description', 'Notification Priority']

# Initialize the list to hold the generated rows
rows = []

# Function to generate data
def generate_data(num_rows):
    total_generated = 0
    while total_generated < num_rows:
        try:
            # Adjust the number of tokens to ensure sufficient data is generated each time
            completion = client.chat.completions.create(
                model="llama-3.3-70b-specdec",
                messages=[
                    {
                        "role": "system",
                        "content": (
                            "You are an expert in news content analysis and dataset generation for machine learning models. "
                            "Your goal is to create a high-quality CSV dataset specifically for a Nepali news application. "
                            "The dataset should include the following fields:\n"
                            "1. **Headline**: The main title of the news article.\n"
                            "2. **Description**: A brief body of the news article.\n"
                            "3. **Notification Priority**: A binary value (1 or 0), where:\n"
                            "- 1 indicates the article is highly relevant and should be sent as a notification.\n"
                            "- 0 indicates the article is not suitable for notification.\n"
                            "\n"
                            "Ensure the dataset:\n"
                            "- Contains diverse news categories like Employment, Sports, Tourism, Auto, National News, "
                            "Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, Education, "
                            "and World.\n"
                            "- Prioritizes news relevance, urgency, and potential user interest for notification prioritization.\n"
                            "- Focuses on the Nepali context, using culturally and socially relevant topics.\n"
                            "- Avoids bias and ensures balance in the selection process.\n"
                            "\n"
                            "Generate realistic samples that align with user preferences for push notifications. "
                            "Include headlines and descriptions in Nepali. Provide 100 examples in CSV format."
                        ),
                    },
                    {
                        "role": "user",
                        "content": (
                            "I am developing a news app with a notification section. I want to integrate a machine learning model "
                            "that takes two parameters: headline and body of the news. The model will categorize which news to send "
                            "as notifications.\n\n"
                            "Please help create a Nepali dataset with:\n"
                            "1. Headline: The main title of the news article.\n"
                            "2. Description: A brief summary of the news article.\n"
                            "3. Notification Priority: A binary value (1 for include in notification, 0 for not include).\n\n"
                            "The dataset should include news from diverse categories such as Employment, Sports, Tourism, Auto, "
                            "National News, Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, "
                            "Education, and World. Ensure it reflects culturally relevant topics and avoids bias.\n\n"
                            "Generate realistic samples in csv format taking Headline before first comma Description before second "
                            "comma and Notification Priority after second comma in Nepali that align with user preferences for notifications."
                        ),
                    },
                ],
                temperature=0.68,
                max_tokens=210,
                top_p=1,
                stream=True,
            )

            # Stream the output and collect data
            for chunk in completion:
                # Extract the generated content and append it to the rows
                content = chunk.choices[0].delta.content or ""
                if content:
                    lines = content.strip().split("\n")
                    for line in lines:
                        if line.strip():
                            row = line.split(",")
                            if len(row) == 3:
                                rows.append(row)
                                total_generated += 1
                                
                                # Stop if we have reached the target number of rows
                                if total_generated >= num_rows:
                                    return
        except RequestException as e:
            # Handle API rate limit error
            error_message = str(e)
            if "Rate limit reached" in error_message:
                # Extract wait time from error message and pause before retrying
                wait_time = int(error_message.split("in ")[1].split("s")[0]) + 10  # Add a buffer of 10 seconds
                print(f"Rate limit reached. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                # Other request errors
                print(f"Request error: {error_message}")
                break

# Generate 50 rows of data
generate_data(10)

# Write the results to a CSV file
with open(output_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(fields)  # Write the header
    writer.writerows(rows)   # Write the rows

print(f"Generated {len(rows)} rows of data and saved to {output_file}.")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 111
#     108                 break
#     110 # Generate 50 rows of data
# --> 111 generate_data(10)
#     113 # Write the results to a CSV file
#     114 with open(output_file, mode='w', newline='', encoding='utf-8') as file:
#
# Cell In[4], line 30, in generate_data(num_rows)
#      27 while total_generated < num_rows:
#      28     try:
#      29         # Adjust the number of tokens to ensure sufficient data is generated each time
# ---> 30         completion = client.chat.completions.create(
#      31             model="llama-3.3-70b-specdec",
#      32             messages=[
#      33                 {
#      34                     "role": "system",
#      35                     "content": (
#      36                         "You are an expert in news content analysis and dataset generation for machine learning models. "
#      37                         "Your goal is to create a high-quality CSV dataset specifically for a Nepali news application. "
#      38                         "The dataset should include the following fields:\n"
#      39                         "1. **Headline**: The main title of the news article.\n"
#      40                         "2. **Description**: A brief body of the news article.\n"
#      41                         "3. **Notification Priority**: A binary value (1 or 0), where:\n"
#      42                         "- 1 indicates the article is highly relevant and should be sent as a notification.\n"
#      43                         "- 0 indicates the article is not suitable for notification.\n"
#      44                         "\n"
#      45                         "Ensure the dataset:\n"
#      46                         "- Contains diverse news categories like Employment, Sports, Tourism, Auto, National News, "
#      47                         "Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, Education, "
#      48                         "and World.\n"
#      49                         "- Prioritizes news relevance, urgency, and potential user interest for notification prioritization.\n"
#      50                         "- Focuses on the Nepali context, using culturally and socially relevant topics.\n"
#      51                         "- Avoids bias and ensures balance in the selection process.\n"
#      52                         "\n"
#      53                         "Generate realistic samples that align with user preferences for push notifications. "
#      54                         "Include headlines and descriptions in Nepali. Provide 100 examples in CSV format."
#      55                     ),
#      56                 },
#      57                 {
#      58                     "role": "user",
#      59                     "content": (
#      60                         "I am developing a news app with a notification section. I want to integrate a machine learning model "
#      61                         "that takes two parameters: headline and body of the news. The model will categorize which news to send "
#      62                         "as notifications.\n\n"
#      63                         "Please help create a Nepali dataset with:\n"
#      64                         "1. Headline: The main title of the news article.\n"
#      65                         "2. Description: A brief summary of the news article.\n"
#      66                         "3. Notification Priority: A binary value (1 for include in notification, 0 for not include).\n\n"
#      67                         "The dataset should include news from diverse categories such as Employment, Sports, Tourism, Auto, "
#      68                         "National News, Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, "
#      69                         "Education, and World. Ensure it reflects culturally relevant topics and avoids bias.\n\n"
#      70                         "Generate realistic samples in csv format taking Headline before first comma Description before second "
#      71                         "comma and Notification Priority after second comma in Nepali that align with user preferences for notifications."
#      72                     ),
#      73                 },
#      74             ],
#      75             temperature=0.68,
#      76             max_tokens=210,
#      77             top_p=1,
#      78             stream=True,
#      79         )
#      81         # Stream the output and collect data
#      82         for chunk in completion:
#      83             # Extract the generated content and append it to the rows
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\resources\chat\completions.py:298, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     157 def create(
#     158     self,
#     159     *,
#    (...)
#     186     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     188     """
#     189     Creates a model response for the given chat conversation.
#     190
#    (...)
#     296       timeout: Override the client-level default timeout for this request, in seconds
#     297     """
# --> 298     return self._post(
#     299         "/openai/v1/chat/completions",
#     300         body=maybe_transform(
#     301             {
#     302                 "messages": messages,
#     303                 "model": model,
#     304                 "frequency_penalty": frequency_penalty,
#     305                 "function_call": function_call,
#     306                 "functions": functions,
#     307                 "logit_bias": logit_bias,
#     308                 "logprobs": logprobs,
#     309                 "max_tokens": max_tokens,
#     310                 "n": n,
#     311                 "parallel_tool_calls": parallel_tool_calls,
#     312                 "presence_penalty": presence_penalty,
#     313                 "response_format": response_format,
#     314                 "seed": seed,
#     315                 "stop": stop,
#     316                 "stream": stream,
#     317                 "temperature": temperature,
#     318                 "tool_choice": tool_choice,
#     319                 "tools": tools,
#     320                 "top_logprobs": top_logprobs,
#     321                 "top_p": top_p,
#     322                 "user": user,
#     323             },
#     324             completion_create_params.CompletionCreateParams,
#     325         ),
#     326         options=make_request_options(
#     327             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     328         ),
#     329         cast_to=ChatCompletion,
#     330         stream=stream or False,
#     331         stream_cls=Stream[ChatCompletionChunk],
#     332     )
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\_base_client.py:1263, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1249 def post(
#    1250     self,
#    1251     path: str,
#    (...)
#    1258     stream_cls: type[_StreamT] | None = None,
#    1259 ) -> ResponseT | _StreamT:
#    1260     opts = FinalRequestOptions.construct(
#    1261         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1262     )
# -> 1263     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055         err.response.read()
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-specdec` in organization `org_01jen5ws1pesw934maz8j3txpv` on : Limit 250000, Used 250352, Requested 545. Please try again in 5m10.259199999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}

# %%
import os
import csv
from dotenv import load_dotenv
from groq import Groq

# Load environment variables from .env file
load_dotenv()

# Get the API key
api_key = os.getenv("GROQ_API_KEY")

# Initialize the Groq client with the API key
client = Groq(api_key=api_key)

# Prepare CSV file to save the results
output_file = "nepali_news_dataset.csv"
fields = ['Headline', 'Description', 'Notification Priority']

# Initialize the list to hold the generated rows
rows = []

# Function to generate data
def generate_data(num_rows):
    total_generated = 0
    while total_generated < num_rows:
        # Adjust the number of tokens to ensure sufficient data is generated each time
        completion = client.chat.completions.create(
            model="llama-3.3-70b-specdec",
            messages=[
                {
                    "role": "system",
                    "content": (
                        "You are an expert in news content analysis and dataset generation for machine learning models. "
                        "Your goal is to create a high-quality CSV dataset specifically for a Nepali news application. "
                        "The dataset should include the following fields:\n"
                        "1. **Headline**: The main title of the news article.\n"
                        "2. **Description**: A brief body of the news article.\n"
                        "3. **Notification Priority**: A binary value (1 or 0), where:\n"
                        "- 1 indicates the article is highly relevant and should be sent as a notification.\n"
                        "- 0 indicates the article is not suitable for notification.\n"
                        "\n"
                        "Ensure the dataset:\n"
                        "- Contains diverse news categories like Employment, Sports, Tourism, Auto, National News, "
                        "Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, Education, "
                        "and World.\n"
                        "- Prioritizes news relevance, urgency, and potential user interest for notification prioritization.\n"
                        "- Focuses on the Nepali context, using culturally and socially relevant topics.\n"
                        "- Avoids bias and ensures balance in the selection process.\n"
                        "\n"
                        "Generate realistic samples that align with user preferences for push notifications. "
                        "Include headlines and descriptions in Nepali. Provide 100 examples in CSV format."
                    ),
                },
                {
                    "role": "user",
                    "content": (
                        "I am developing a news app with a notification section. I want to integrate a machine learning model "
                        "that takes two parameters: headline and body of the news. The model will categorize which news to send "
                        "as notifications.\n\n"
                        "Please help create a Nepali dataset with:\n"
                        "1. Headline: The main title of the news article.\n"
                        "2. Description: A brief summary of the news article.\n"
                        "3. Notification Priority: A binary value (1 for include in notification, 0 for not include).\n\n"
                        "The dataset should include news from diverse categories such as Employment, Sports, Tourism, Auto, "
                        "National News, Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, "
                        "Education, and World. Ensure it reflects culturally relevant topics and avoids bias.\n\n"
                        "Generate realistic samples in csv format taking Headline before first comma Description before second "
                        "comma and Notification Priority after second comma in Nepali that align with user preferences for notifications."
                    ),
                },
            ],
            temperature=0.68,
            max_tokens=210,
            top_p=1,
            stream=True,
        )
        
        # Stream the output and collect data
        for chunk in completion:
            # Extract the generated content and append it to the rows
            content = chunk.choices[0].delta.content or ""
            if content:
                lines = content.strip().split("\n")
                for line in lines:
                    if line.strip():
                        row = line.split(",")
                        if len(row) == 3:
                            rows.append(row)
                            total_generated += 1
                            
                            # Stop if we have reached the target number of rows
                            if total_generated >= num_rows:
                                return
    
# Generate 50 rows of data
generate_data(10)

# Write the results to a CSV file
with open(output_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(fields)  # Write the header
    writer.writerows(rows)   # Write the rows

print(f"Generated {len(rows)} rows of data and saved to {output_file}.")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[1], line 96
#      93                                 return
#      95 # Generate 50 rows of data
# ---> 96 generate_data(10)
#      98 # Write the results to a CSV file
#      99 with open(output_file, mode='w', newline='', encoding='utf-8') as file:
#
# Cell In[1], line 27, in generate_data(num_rows)
#      24 total_generated = 0
#      25 while total_generated < num_rows:
#      26     # Adjust the number of tokens to ensure sufficient data is generated each time
# ---> 27     completion = client.chat.completions.create(
#      28         model="llama-3.3-70b-specdec",
#      29         messages=[
#      30             {
#      31                 "role": "system",
#      32                 "content": (
#      33                     "You are an expert in news content analysis and dataset generation for machine learning models. "
#      34                     "Your goal is to create a high-quality CSV dataset specifically for a Nepali news application. "
#      35                     "The dataset should include the following fields:\n"
#      36                     "1. **Headline**: The main title of the news article.\n"
#      37                     "2. **Description**: A brief body of the news article.\n"
#      38                     "3. **Notification Priority**: A binary value (1 or 0), where:\n"
#      39                     "- 1 indicates the article is highly relevant and should be sent as a notification.\n"
#      40                     "- 0 indicates the article is not suitable for notification.\n"
#      41                     "\n"
#      42                     "Ensure the dataset:\n"
#      43                     "- Contains diverse news categories like Employment, Sports, Tourism, Auto, National News, "
#      44                     "Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, Education, "
#      45                     "and World.\n"
#      46                     "- Prioritizes news relevance, urgency, and potential user interest for notification prioritization.\n"
#      47                     "- Focuses on the Nepali context, using culturally and socially relevant topics.\n"
#      48                     "- Avoids bias and ensures balance in the selection process.\n"
#      49                     "\n"
#      50                     "Generate realistic samples that align with user preferences for push notifications. "
#      51                     "Include headlines and descriptions in Nepali. Provide 100 examples in CSV format."
#      52                 ),
#      53             },
#      54             {
#      55                 "role": "user",
#      56                 "content": (
#      57                     "I am developing a news app with a notification section. I want to integrate a machine learning model "
#      58                     "that takes two parameters: headline and body of the news. The model will categorize which news to send "
#      59                     "as notifications.\n\n"
#      60                     "Please help create a Nepali dataset with:\n"
#      61                     "1. Headline: The main title of the news article.\n"
#      62                     "2. Description: A brief summary of the news article.\n"
#      63                     "3. Notification Priority: A binary value (1 for include in notification, 0 for not include).\n\n"
#      64                     "The dataset should include news from diverse categories such as Employment, Sports, Tourism, Auto, "
#      65                     "National News, Entertainment, Opinion, Bank, Blog, Economy, Literature, Business Interview, Technology, "
#      66                     "Education, and World. Ensure it reflects culturally relevant topics and avoids bias.\n\n"
#      67                     "Generate realistic samples in csv format taking Headline before first comma Description before second "
#      68                     "comma and Notification Priority after second comma in Nepali that align with user preferences for notifications."
#      69                 ),
#      70             },
#      71         ],
#      72         temperature=0.68,
#      73         max_tokens=210,
#      74         top_p=1,
#      75         stream=True,
#      76     )
#      78     # Stream the output and collect data
#      79     for chunk in completion:
#      80         # Extract the generated content and append it to the rows
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\resources\chat\completions.py:298, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     157 def create(
#     158     self,
#     159     *,
#    (...)
#     186     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     188     """
#     189     Creates a model response for the given chat conversation.
#     190
#    (...)
#     296       timeout: Override the client-level default timeout for this request, in seconds
#     297     """
# --> 298     return self._post(
#     299         "/openai/v1/chat/completions",
#     300         body=maybe_transform(
#     301             {
#     302                 "messages": messages,
#     303                 "model": model,
#     304                 "frequency_penalty": frequency_penalty,
#     305                 "function_call": function_call,
#     306                 "functions": functions,
#     307                 "logit_bias": logit_bias,
#     308                 "logprobs": logprobs,
#     309                 "max_tokens": max_tokens,
#     310                 "n": n,
#     311                 "parallel_tool_calls": parallel_tool_calls,
#     312                 "presence_penalty": presence_penalty,
#     313                 "response_format": response_format,
#     314                 "seed": seed,
#     315                 "stop": stop,
#     316                 "stream": stream,
#     317                 "temperature": temperature,
#     318                 "tool_choice": tool_choice,
#     319                 "tools": tools,
#     320                 "top_logprobs": top_logprobs,
#     321                 "top_p": top_p,
#     322                 "user": user,
#     323             },
#     324             completion_create_params.CompletionCreateParams,
#     325         ),
#     326         options=make_request_options(
#     327             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     328         ),
#     329         cast_to=ChatCompletion,
#     330         stream=stream or False,
#     331         stream_cls=Stream[ChatCompletionChunk],
#     332     )
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\_base_client.py:1263, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1249 def post(
#    1250     self,
#    1251     path: str,
#    (...)
#    1258     stream_cls: type[_StreamT] | None = None,
#    1259 ) -> ResponseT | _StreamT:
#    1260     opts = FinalRequestOptions.construct(
#    1261         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1262     )
# -> 1263     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File c:\Users\N I T R O V15\AppData\Local\Programs\Python\Python310\lib\site-packages\groq\_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055         err.response.read()
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.3-70b-specdec` in organization `org_01jen5ws1pesw934maz8j3txpv` on : Limit 250000, Used 252121, Requested 545. Please try again in 15m21.410199999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
